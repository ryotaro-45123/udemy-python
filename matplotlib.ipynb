# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-10, 10, 10)
z = 1 / (1 + np.exp(-x))

# %%
plt.plot(x, z,
        color='red',
        lw=3,
        ls='--',
        marker='x',
        markersize=10,
        markerfacecolor='yellow',
        alpha=0.2)

# %% [markdown]
# ### 装飾

# %%
plt.plot(x, z, 'k--')

# %% [markdown]
# ### 付属情報

# %%
plt.plot(x, z, label='sig')
plt.xlabel('x')
plt.title('sigmoid')
plt.legend(loc=4)
plt.xticks([1, 2, 3], rotation=20)
# Out:
# ([<matplotlib.axis.XTick at 0x7f12e9a05460>,
# ...
#  <a list of 3 Text major ticklabel objects>)

# %% [markdown]
# ### exercise

# %%
df = pd.read_csv('tmdb_5000_movies.csv')

# %%
df['release_year'] = df['release_date'].apply(release)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-42-d51b029efd1d> in <module>
# ----> 1 df['release_year'] = df['release_date'].apply(release)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-41-d5390a50660e> in release(str)
#       1 def release(str):
# ----> 2     return str[:4]
#
# TypeError: 'float' object is not subscriptable

# %%
df['release_date'].iloc[0][:4]
# Out:
# '2009'

# %%
def release(str):
    return str[:4]

# %%
df.dropna(subset=('release_date'))
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-44-774a78503bec> in <module>
# ----> 1 df.dropna(subset=('release_date'))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4743         if subset is not None:
#    4744             ax = self._get_axis(agg_axis)
# -> 4745             indices = ax.get_indexer_for(subset)
#    4746             check = indices == -1
#    4747             if check.any():
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    4500         """
#    4501         if self.is_unique:
# -> 4502             return self.get_indexer(target, **kwargs)
#    4503         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4504         return indexer
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
# ...
